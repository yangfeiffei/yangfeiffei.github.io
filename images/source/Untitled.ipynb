# %%
import numpy as np
import matplotlib.plot as plt
def my_sinplot(flip=1):
    x = np.linspace(0, 14, 100)
    for i in range(1,7):
        plt.plot(x, np.sin(x,i*0.5) * (7 - i)*flip)
# Out:
#   File "<ipython-input-1-9f1f88e6b279>", line 1
#     from numpy as np
#                 ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import matplotlib.pyplot as plt
def my_sinplot(flip=1):
    x = np.linspace(0, 14, 100)
    for i in range(1,7):
        plt.plot(x, np.sin(x + i*0.5)*(7 - i)*flip)
my_sinplot()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0, 14, 100)
plt.plot(x, np.sin(x + 1*0.5)*(7 - 1)*1)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
def my_sinplot(flip=1):
    x = np.linspace(0, 14, 100)
    for i in range(1,7):
        plt.plot(x, np.sin(x + i*0.5)*(7 - i)*flip)
import seaborn as sns
my_sinplot()
plt.show()
